# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Dec 10 15:31:22 2016

@author: Duc-Vinh
""" 

import numpy as np
from random import randint
from skimage import color
from skimage import feature
from skimage import io
from skimage import segmentation
from skimage import draw
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
#To delete for production purpose
# %matplotlib inline

import scipy
from scipy import misc

# %%
def display_picture(picture, particles, weights):


    fig,ax = plt.subplots(1)


    #Display picture
    ax.imshow(picture)

    #Deactivate autoscale to have clean window
    ax.autoscale(False)

    #Plot particles with weights
    s=weights*20  #size vector
    ax.scatter(particles["x"], particles["y"], marker="o", s=s)

   
    plt.show()

# %%
image = io.imread("../../data/sequence1/sequence10000.png")   
particle_number = 500

weights_0= np.array([(1.0/particle_number) for x in range(particle_number)])
weights_0=np.tile(1.0/particle_number,particle_number) #more compact
weights=np.random.rand(particle_number)

#First init
    #generate random particles around a fixed point
    #take center of face for this point

#for simple purpose, take random point
x_init=np.array([[randint(0,image.shape[1])],[randint(0,image.shape[0])]])
particles_mat=np.tile(x_init,(1,particle_number))


weights_0= np.array([(1.0/particle_number) for x in range(particle_number)])
weights=np.random.rand(particle_number)

#Random data example to show you the structure
#particles = {}
#particles["x"] = np.random.rand(particle_number) * image.shape[1]
#particles["y"] = np.random.rand((particle_number)) * image.shape[0]
#particles["weights"] = np.random.rand(particle_number)

# %%
weights_0=np.tile(1.0/particle_number,particle_number)

# %%
particles_mat.shape
# Out:
# (2, 500)

# %%
# Out:
# 7

# %%
#Display picture/particles/ellipse
display_picture(picture=image, particles=particles, weights=weights)

# %%
#resampling
def resample(particles,weights):
    n_particles=len(particles['x'])
    c=

# %%
#particle generation

         #initialisation

# %%
#weighing

#resampling
